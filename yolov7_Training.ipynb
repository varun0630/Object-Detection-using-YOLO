# %% [markdown]
# <a href="https://colab.research.google.com/github/varun0630/Object-Detection-using-YOLO/blob/main/yolov7_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installing Dependenices

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1088, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 1088 (delta 18), reused 79 (delta 16), pack-reused 998
# Receiving objects: 100% (1088/1088), 69.97 MiB | 15.95 MiB/s, done.
# Resolving deltas: 100% (484/484), done.

# %%
# %cd yolov7
# !pip install -r requirements.txt

# %% [markdown]
# # Importing RoboFlow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/yolov7
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7x.pt

# %%
# %cd /content/yolov7
# !unzip /content/drive/MyDrive/yolov7_Dataset.zip

# %% [markdown]
# # Training Custom Dataset

# %%
# %cd /content/yolov7
# !python train.py --batch 16 --cfg cfg/training/yolov7.yaml --epochs 100 --data yolov7_Dataset/data.yaml --weights 'yolov7x.pt' --device 0
# Out:
# /content/yolov7
# YOLOR 🚀 v0.1-115-g072f76c torch 1.12.1+cu113 CUDA:0 (A100-SXM4-40GB, 40536.1875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='yolov7_Dataset/data.yaml', device='0', entity=None, epochs=100, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.p5.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, v5_metric=False, weights='yolov7x.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %% [markdown]
# # Evaluation

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --conf 0.1 --source yolov7_Dataset/test/images
# Out:
# Streaming output truncated to the last 5000 lines.
#  The image with the result is saved in: runs/detect/exp/image6308.png
# 1 armor_red, Done. (11.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs/detect/exp/image6309.png
# 1 armor_red, Done. (11.2ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp/image631.png
# 1 armor_red, Done. (11.1ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp/image6310.png
# 2 armor_reds, Done. (11.4ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp/image6311.png
# 1 armor_red, Done. (11.3ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp/image6312.png
# 1 armor_red, Done. (11.1ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp/image6313.png
# 2 armor_reds, Done. (11.3ms) Inference, (1.0ms) NMS
# ...

# %%
import glob
from IPython.display import Image,display

i=0
limit = 10000
for imageName in glob.glob(('/content/yolov7/runs/detect/exp/*.jpg')):
  if i<limit:
    display(Image(filename=imageName))
    print("\n")
  i=i+1

# %%
import yaml
yaml.__version__
# Out:
# '6.0'
